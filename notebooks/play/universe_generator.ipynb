# %%
import fastf1

# %% [markdown]
# ## Schedule

# %%
year = 2025

event_schedule_df_raw = fastf1.get_event_schedule(year)
event_schedule_df_raw.iloc[:1]
# Out:
#    RoundNumber  Country Location                         OfficialEventName  \
# 0            0  Bahrain   Sakhir  FORMULA 1 ARAMCO PRE-SEASON TESTING 2025
#
#    EventDate           EventName EventFormat    Session1  \
# 0 2025-02-28  Pre-Season Testing     testing  Practice 1
#
#                 Session1Date     Session1DateUtc  ...    Session3  \
# 0  2025-02-26 10:00:00+03:00 2025-02-26 07:00:00  ...  Practice 3
#
#                 Session3Date     Session3DateUtc Session4 Session4Date  \
# 0  2025-02-28 10:00:00+03:00 2025-02-28 07:00:00     None          NaT
#
#   Session4DateUtc Session5 Session5Date Session5DateUtc F1ApiSupport
# 0             NaT     None          NaT             NaT         True
#
# [1 rows x 23 columns]

# %% [markdown]
# ## Session

# %%
event_quali = fastf1.get_event(year, 2)
quali_2 = event_quali.get_qualifying()
quali_2.load(laps=False, telemetry=False, weather=False, messages=False)
quali_2.results
# Out:
# core           INFO 	Loading data for Chinese Grand Prix - Qualifying [v3.8.3]
# req            INFO 	No cached data found for session_info. Loading data...
# _api           INFO 	Fetching session info data...
# req            INFO 	Data has been written to cache!
# req            INFO 	No cached data found for driver_info. Loading data...
# _api           INFO 	Fetching driver list...
# req            INFO 	Data has been written to cache!
# core           INFO 	Finished loading data for 20 drivers: ['81', '63', '4', '1', '44', '16', '6', '12', '22', '23', '31', '27', '14', '18', '55', '10', '87', '7', '5', '30']
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 63           63     G RUSSELL          RUS         russell         Mercedes
# 4             4      L NORRIS          NOR          norris          McLaren
# ...

# %%
event_quali = fastf1.get_event(year, 2)
race_2 = event_quali.get_race()
race_2.load(laps=False, telemetry=False, weather=False, messages=False)
race_2.results
# Out:
# core           INFO 	Loading data for Chinese Grand Prix - Race [v3.8.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# core           INFO 	Finished loading data for 20 drivers: ['81', '4', '63', '1', '31', '12', '23', '87', '18', '55', '6', '30', '7', '5', '27', '22', '14', '16', '44', '10']
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 4             4      L NORRIS          NOR          norris          McLaren
# 63           63     G RUSSELL          RUS         russell         Mercedes
# 1             1  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 31           31        E OCON          OCO            ocon     Haas F1 Team
# 12           12   K ANTONELLI          ANT       antonelli         Mercedes
# 23           23       A ALBON          ALB           albon         Williams
# ...
