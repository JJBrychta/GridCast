# %%
import fastf1
from racecast.cache import enable_cache

enable_cache()

# %%
season = 2026
round_number = 10
Q = "qualifying"
R = "race"

# %%
quali_session = fastf1.get_session(season, round_number, Q)
quali_session.load(laps=False, telemetry=False, weather=False, messages=False)
quali_session.results
# Out:
# core           INFO 	Loading data for Belgian Grand Prix - Qualifying [v3.8.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# core           INFO 	Finished loading data for 22 drivers: ['12', '3', '1', '63', '16', '44', '81', '41', '5', '6', '30', '10', '43', '27', '55', '87', '23', '31', '77', '11', '14', '18']
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 12           12   K ANTONELLI          ANT       antonelli         Mercedes
# 3             3  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 1             1      L NORRIS          NOR          norris          McLaren
# 63           63     G RUSSELL          RUS         russell         Mercedes
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 44           44    L HAMILTON          HAM        hamilton          Ferrari
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 41           41    A LINDBLAD          LIN  arvid_lindblad     Racing Bulls
# 5             5   G BORTOLETO          BOR       bortoleto             Audi
# 6             6      I HADJAR          HAD          hadjar  Red Bull Racing
# 30           30      L LAWSON          LAW          lawson     Racing Bulls
# 10           10       P GASLY          GAS           gasly           Alpine
# 43           43   F COLAPINTO          COL       colapinto           Alpine
# 27           27  N HULKENBERG          HUL      hulkenberg             Audi
# 55           55       C SAINZ          SAI           sainz         Williams
# 87           87     O BEARMAN          BEA         bearman     Haas F1 Team
# 23           23       A ALBON          ALB           albon         Williams
# 31           31        E OCON          OCO            ocon     Haas F1 Team
# 77           77      V BOTTAS          BOT          bottas         Cadillac
# 11           11       S PEREZ          PER           perez         Cadillac
# 14           14      F ALONSO          ALO          alonso     Aston Martin
# 18           18      L STROLL          STR          stroll     Aston Martin
#
#    TeamColor        TeamId  FirstName    LastName           FullName  ...  \
# 12    00D7B6      mercedes       Kimi   Antonelli     Kimi Antonelli  ...
# 3     4781D7      red_bull        Max  Verstappen     Max Verstappen  ...
# 1     F47600       mclaren      Lando      Norris       Lando Norris  ...
# 63    00D7B6      mercedes     George     Russell     George Russell  ...
# 16    ED1131       ferrari    Charles     Leclerc    Charles Leclerc  ...
# 44    ED1131       ferrari      Lewis    Hamilton     Lewis Hamilton  ...
# 81    F47600       mclaren      Oscar     Piastri      Oscar Piastri  ...
# 41    6C98FF            rb      Arvid    Lindblad     Arvid Lindblad  ...
# 5     F50537          audi    Gabriel   Bortoleto  Gabriel Bortoleto  ...
# 6     4781D7      red_bull      Isack      Hadjar       Isack Hadjar  ...
# 30    6C98FF            rb       Liam      Lawson        Liam Lawson  ...
# 10    00A1E8        alpine     Pierre       Gasly       Pierre Gasly  ...
# 43    00A1E8        alpine     Franco   Colapinto   Franco Colapinto  ...
# 27    F50537          audi       Nico  Hulkenberg    Nico Hulkenberg  ...
# 55    1868DB      williams     Carlos       Sainz       Carlos Sainz  ...
# 87    9C9FA2          haas     Oliver     Bearman     Oliver Bearman  ...
# 23    1868DB      williams  Alexander       Albon    Alexander Albon  ...
# 31    9C9FA2          haas    Esteban        Ocon       Esteban Ocon  ...
# 77    909090      cadillac   Valtteri      Bottas    Valtteri Bottas  ...
# core           INFO 	Loading data for Belgian Grand Prix - Race [v3.8.3]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# core           INFO 	Finished loading data for 22 drivers: ['12', '16', '3', '44', '81', '6', '1', '5', '41', '43', '10', '30', '27', '87', '23', '55', '31', '77', '14', '18', '11', '63']
#    DriverNumber BroadcastName Abbreviation        DriverId         TeamName  \
# 12           12   K ANTONELLI          ANT       antonelli         Mercedes
# 16           16     C LECLERC          LEC         leclerc          Ferrari
# 3             3  M VERSTAPPEN          VER  max_verstappen  Red Bull Racing
# 44           44    L HAMILTON          HAM        hamilton          Ferrari
# 81           81     O PIASTRI          PIA         piastri          McLaren
# 6             6      I HADJAR          HAD          hadjar  Red Bull Racing
# 1             1      L NORRIS          NOR          norris          McLaren
# 5             5   G BORTOLETO          BOR       bortoleto             Audi
# 41           41    A LINDBLAD          LIN  arvid_lindblad     Racing Bulls
# 43           43   F COLAPINTO          COL       colapinto           Alpine
# 10           10       P GASLY          GAS           gasly           Alpine
# 30           30      L LAWSON          LAW          lawson     Racing Bulls
# 27           27  N HULKENBERG          HUL      hulkenberg             Audi
# 87           87     O BEARMAN          BEA         bearman     Haas F1 Team
# 23           23       A ALBON          ALB           albon         Williams
# 55           55       C SAINZ          SAI           sainz         Williams
# 31           31        E OCON          OCO            ocon     Haas F1 Team
# 77           77      V BOTTAS          BOT          bottas         Cadillac
# 14           14      F ALONSO          ALO          alonso     Aston Martin
# 18           18      L STROLL          STR          stroll     Aston Martin
# 11           11       S PEREZ          PER           perez         Cadillac
# 63           63     G RUSSELL          RUS         russell         Mercedes
#
#    TeamColor        TeamId  FirstName    LastName           FullName  ...  \
# 12    00D7B6      mercedes       Kimi   Antonelli     Kimi Antonelli  ...
# 16    ED1131       ferrari    Charles     Leclerc    Charles Leclerc  ...
# 3     4781D7      red_bull        Max  Verstappen     Max Verstappen  ...
# 44    ED1131       ferrari      Lewis    Hamilton     Lewis Hamilton  ...
# 81    F47600       mclaren      Oscar     Piastri      Oscar Piastri  ...
# 6     4781D7      red_bull      Isack      Hadjar       Isack Hadjar  ...
# 1     F47600       mclaren      Lando      Norris       Lando Norris  ...
# 5     F50537          audi    Gabriel   Bortoleto  Gabriel Bortoleto  ...
# 41    6C98FF            rb      Arvid    Lindblad     Arvid Lindblad  ...
# 43    00A1E8        alpine     Franco   Colapinto   Franco Colapinto  ...
# 10    00A1E8        alpine     Pierre       Gasly       Pierre Gasly  ...
# 30    6C98FF            rb       Liam      Lawson        Liam Lawson  ...
# 27    F50537          audi       Nico  Hulkenberg    Nico Hulkenberg  ...
# 87    9C9FA2          haas     Oliver     Bearman     Oliver Bearman  ...
# 23    1868DB      williams  Alexander       Albon    Alexander Albon  ...
# 55    1868DB      williams     Carlos       Sainz       Carlos Sainz  ...
# 31    9C9FA2          haas    Esteban        Ocon       Esteban Ocon  ...
# 77    909090      cadillac   Valtteri      Bottas    Valtteri Bottas  ...
# 14    229971  aston_martin   Fernando      Alonso    Fernando Alonso  ...
# 18    229971  aston_martin      Lance      Stroll       Lance Stroll  ...
# 11    909090      cadillac     Sergio       Perez       Sergio Perez  ...
# 63    00D7B6      mercedes     George     Russell     George Russell  ...
#
#    Position ClassifiedPosition  GridPosition  Q1  Q2  Q3  \
# 12      1.0                  1           1.0 NaT NaT NaT
# 16      2.0                  2           4.0 NaT NaT NaT
# 3       3.0                  3           2.0 NaT NaT NaT
# 44      4.0                  4           5.0 NaT NaT NaT
# 81      5.0                  5           6.0 NaT NaT NaT
# 6       6.0                  6          21.0 NaT NaT NaT
# 1       7.0                  7          13.0 NaT NaT NaT
# 5       8.0                  8           8.0 NaT NaT NaT
# 41      9.0                  9           7.0 NaT NaT NaT
# 43     10.0                 10          11.0 NaT NaT NaT
# 10     11.0                 11          10.0 NaT NaT NaT
# 30     12.0                 12           9.0 NaT NaT NaT
# 27     13.0                 13          12.0 NaT NaT NaT
# 87     14.0                 14          14.0 NaT NaT NaT
# 23     15.0                 15          15.0 NaT NaT NaT
# 55     16.0                 16          19.0 NaT NaT NaT
# 31     17.0                 17          16.0 NaT NaT NaT
# 77     18.0                 18          17.0 NaT NaT NaT
# 14     19.0                 19          22.0 NaT NaT NaT
# 18     20.0                  R          20.0 NaT NaT NaT
# 11     21.0                  R          18.0 NaT NaT NaT
# 63     22.0                  R           3.0 NaT NaT NaT
#
#                      Time    Status Points  Laps
# 12 0 days 01:24:42.479000  Finished   25.0  44.0
# 16 0 days 00:00:01.952000  Finished   18.0  44.0
# 3  0 days 00:00:11.586000  Finished   15.0  44.0
# 44 0 days 00:00:17.245000  Finished   12.0  44.0
# 81 0 days 00:00:18.988000  Finished   10.0  44.0
# 6  0 days 00:00:23.307000  Finished    8.0  44.0
# 1  0 days 00:00:24.014000  Finished    6.0  44.0
# 5  0 days 00:00:49.140000  Finished    4.0  44.0
# 41 0 days 00:00:50.406000  Finished    2.0  44.0
# 43 0 days 00:01:16.037000  Finished    1.0  44.0
# 10 0 days 00:01:16.991000  Finished    0.0  44.0
# 30 0 days 00:01:17.523000  Finished    0.0  44.0
# 27 0 days 00:01:18.348000  Finished    0.0  44.0
# 87 0 days 00:01:34.465000  Finished    0.0  44.0
# 23 0 days 00:01:44.684000  Finished    0.0  44.0
# 55 0 days 00:01:45.856000  Finished    0.0  44.0
# 31 0 days 00:01:50.925000  Finished    0.0  44.0
# 77 0 days 00:01:00.979000    Lapped    0.0  43.0
# 14 0 days 00:00:20.848000    Lapped    0.0  42.0
# 18                    NaT   Retired    0.0  25.0
# 11                    NaT   Retired    0.0  13.0
# 63                    NaT   Retired    0.0   0.0
#
# [22 rows x 22 columns]

# %%
quali_session.results.columns.symmetric_difference(race_session.results.columns)
# Out:
# Index([], dtype='object')

# %%
for col in race_session.results.columns:
    print(col)
# Out:
# DriverNumber
# BroadcastName
# Abbreviation
# DriverId
# TeamName
# TeamColor
# TeamId
# FirstName
# LastName
# FullName
# HeadshotUrl
# CountryCode
# Position
# ClassifiedPosition
# GridPosition
# Q1
# Q2
# Q3
# Time
# Status
# Points
# Laps
